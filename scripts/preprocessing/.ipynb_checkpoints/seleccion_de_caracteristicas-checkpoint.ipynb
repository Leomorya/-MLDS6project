# %%
# importanto las librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
import sys
import sklearn
from sklearn.decomposition import PCA
sns.set_style('darkgrid')

print("Version de pandas",pd.__version__)
print("Version de numpy",np.__version__)
print('Version de Matplotlib', mpl.__version__)
print('Version de seaborn', sns.__version__)
print("Version de sklearn",sklearn.__version__)
# !python3 --version
# Out:
# Version de pandas 1.5.2
# Version de numpy 1.23.5
# Version de Matplotlib 3.6.2
# Version de seaborn 0.12.2
# Version de sklearn 1.2.2
# Python 3.10.7

# %%
#Carga de datos
# ruta de los datos
ruta_train_prep=r"/home/leomorya/proyecto_final_metodologias/data/datos_preprocesados_train.csv"
# cargando los datos 
df_train_prep = pd.read_csv(ruta_train_prep)

# %%
df_train_prep.head()
# Out:
#    ID  Edad           Tipo_Trabajo Estado_Civil     Educacion     mora  \
# 0   1    57              servicios       casado  bachillerato  unknown
# 1   2    37              servicios       casado  bachillerato       no
# 2   3    40  administrador negocio       casado      primaria       no
# 3   4    56              servicios       casado  bachillerato       no
# 4   7    25              servicios      soltero  bachillerato       no
#
#   Vivienda Consumo       Contacto  Mes  ... Campana  Dias_Ultima_Camp  \
# 0       no      no  telefono fijo  may  ...       1                 1
# 1       si      no  telefono fijo  may  ...       1                 1
# 2       no      no  telefono fijo  may  ...       1                 1
# 3       no      si  telefono fijo  may  ...       1                 1
# 4       si      no  telefono fijo  may  ...       1                 1
#
#    No_Contactos  Resultado_Anterior emp_var_rate  cons_price_idx  \
# ...

# %% [markdown]
# # Selección de cararcteristicas
# ---
# Para este fin se utilizara las correlciones entre las distintas variables numericas de caracteristicas.

# %%
correlaciones=df_train_prep.drop(columns="ID").corr()
correlaciones
# Out:
# /tmp/ipykernel_30937/453453496.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones=df_train_prep.drop(columns="ID").corr()
#                       Edad   Campana  Dias_Ultima_Camp  No_Contactos  \
# Edad              1.000000  0.003292         -0.039290      0.022755
# Campana           0.003292  1.000000          0.052271     -0.079160
# Dias_Ultima_Camp -0.039290  0.052271          1.000000     -0.584226
# No_Contactos      0.022755 -0.079160         -0.584226      1.000000
# emp_var_rate     -0.002260  0.151806          0.267219     -0.417668
# cons_price_idx    0.009036  0.128860          0.071545     -0.192252
# cons_conf_idx     0.127901 -0.012337         -0.081210     -0.057095
# euribor3m         0.005630  0.136299          0.294850     -0.454730
# ...

# %% [markdown]
# Como vemos la coprrelación solo se plica a las caracteristicas numericas

# %%
plt.subplots(figsize=(12,10))  
sns.heatmap(correlaciones, cmap = "vlag",annot = True,fmt=".2f")
plt.show()

# %% [markdown]
# Como se observa en el mapa de color de la correlacion hay una alta correlacion entre las variables emp_var_rate, euribor3m, nr_employed, grafiquemos para observar

# %%
sns.jointplot(data=df_train_prep, x=val[0], y=val[1],kind="reg");
sns.jointplot(data=df_train_prep, x=val[0], y=val[1],kind="hex");
sns.jointplot(data=df_train_prep, x="emp_var_rate", y="nr_employed",kind="reg");
sns.jointplot(data=df_train_prep, x="emp_var_rate", y="nr_employed",kind="hex");
sns.jointplot(data=df_train_prep, x="euribor3m", y="nr_employed",kind="reg");
sns.jointplot(data=df_train_prep, x="euribor3m", y="nr_employed",kind="hex");

# %% [markdown]
# De las graficas anteriores vemos que aunque hay una alta correlación, tambien se presenta un alta densidad en algunas zonas. Por tanto, no se va a eliminar las variables sino se va realizar un PCA para extraer la mayor cantidad de información en una nueva variable.

# %%
#caracteristicas correlacionedas, tres caracteristicas 
caract_corr=["emp_var_rate","euribor3m","nr_employed"]
df_coor = df_train_prep[caract_corr]
# haciendo el PCA
pca = PCA()
pca.fit(df_coor)
print("Proporción de varianza explicada\n",pca.explained_variance_ratio_)
# Out:
# Proporción de varianza explicada
#  [9.99853954e-01 1.34544544e-04 1.15013219e-05]

# %% [markdown]
# Al observar la varianza explicada vemos que es muy alta en la primera componente, de alrededor del 99%
